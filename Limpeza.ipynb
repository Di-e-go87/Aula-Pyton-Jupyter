# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                INCIDENTE               BELÉM            PA
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                 ****     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 ****     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 1                INCIDENTE               BELÉM            PA
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 ****     2010-01-04        17:30:00                    0

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211
# 40349                           40349               40349
# 40351                           40351               40351
# 39527                           39527               39527
# 40324                           40324               40324
# ...                               ...                 ...
# 80245                           80245               80245
# 80247                           80247               80247
# 80251                           80251               80251
# 80257                           80257               80257
# 80259                           80259               80259
#
#                   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# codigo_ocorrencia
# 40211                            INCIDENTE      RIO DE JANEIRO            RJ
# 40349                            INCIDENTE               BELÉM            PA
# 40351                            INCIDENTE      RIO DE JANEIRO            RJ
# 39527                             ACIDENTE  LUCAS DO RIO VERDE            MT
# 40324                            INCIDENTE             PELOTAS            RS
# ...                                    ...                 ...           ...
# 80245                            INCIDENTE              RECIFE            PE
# 80247                            INCIDENTE         PORTO VELHO            RO
# 80251                            INCIDENTE               BELÉM            PA
# 80257                             ACIDENTE          DOM AQUINO            MT
# 80259                            INCIDENTE            CAMPINAS            SP
#
#                   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# codigo_ocorrencia
# 40211                             ****     2010-01-03        12:00:00
# 40349                             SBBE     2010-01-03        11:05:00
# 40351                             SBRJ     2010-01-03        03:00:00
# 39527                             ****     2010-01-04        17:30:00
# 40324                             SBPK     2010-01-05        19:25:00
# ...                                ...            ...             ...
# 80245                             SBRF     2021-08-15        15:05:00
# 80247                             SBPV     2021-08-16        02:30:00
# 80251                             SBBE     2021-08-17        15:45:00
# 80257                             ****     2021-08-18        16:00:00
# 80259                             SBKP     2021-08-18        12:45:00
#
#                    total_recomendacoes
# codigo_ocorrencia
# 40211                                0
# 40349                                0
# 40351                                0
# 39527                                0
# 40324                                0
# ...                                ...
# 80245                                0
# 80247                                0
# 80251                                0
# 80257                                0
# 80259                                0
#
# [6114 rows x 9 columns]

# %%
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0              40211               40211               40211
#
#   ocorrencia_classificacao ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE    RIO DE JANEIRO            RJ
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                          2010-01-03        12:00:00                    0

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 6109              80245               80245               80245
# 6110              80247               80247               80247
# 6111              80251               80251               80251
# 6112              80257               80257               80257
# 6113              80259               80259               80259
#
#      ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                   INCIDENTE      RIO DE JANEIRO            RJ
# 1                   INCIDENTE               BELÉM            PA
# 2                   INCIDENTE      RIO DE JANEIRO            RJ
# 3                    ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                   INCIDENTE             PELOTAS            RS
# ...                       ...                 ...           ...
# 6109                INCIDENTE              RECIFE            PE
# 6110                INCIDENTE         PORTO VELHO            RO
# 6111                INCIDENTE               BELÉM            PA
# 6112                 ACIDENTE          DOM AQUINO            MT
# 6113                INCIDENTE            CAMPINAS            SP
#
#      ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                    ****     2010-01-03        12:00:00                    0
# 1                    SBBE     2010-01-03        11:05:00                    0
# 2                    SBRJ     2010-01-03        03:00:00                    0
# 3                    ****     2010-01-04        17:30:00                    0
# 4                    SBPK     2010-01-05        19:25:00                    0
# ...                   ...            ...             ...                  ...
# 6109                 SBRF     2021-08-15        15:05:00                    0
# 6110                 SBPV     2021-08-16        02:30:00                    0
# 6111                 SBBE     2021-08-17        15:45:00                    0
# 6112                 ****     2021-08-18        16:00:00                    0
# 6113                 SBKP     2021-08-18        12:45:00                    0
#
# [6114 rows x 10 columns]

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                INCIDENTE               BELÉM            PA
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                 ****     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 ****     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                INCIDENTE               BELÉM            PA
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                 <NA>     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 <NA>     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0

# %% [raw]
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#   ocorrencia_classificacao   ocorrencia_cidade ocorrencia_uf  \
# 0                INCIDENTE      RIO DE JANEIRO            RJ
# 1                INCIDENTE               BELÉM            PA
# 2                INCIDENTE      RIO DE JANEIRO            RJ
# 3                 ACIDENTE  LUCAS DO RIO VERDE            MT
# 4                INCIDENTE             PELOTAS            RS
#
#   ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 0                 <NA>     2010-01-03        12:00:00                    0
# 1                 SBBE     2010-01-03        11:05:00                    0
# 2                 SBRJ     2010-01-03        03:00:00                    0
# 3                 <NA>     2010-01-04        17:30:00                    0
# 4                 SBPK     2010-01-05        19:25:00                    0

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# codigo_ocorrencia3             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# codigo_ocorrencia3             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64
